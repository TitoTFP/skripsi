# %% [markdown]
# # BAB 4 Generator Python
#
# Notebook ini hanya melakukan orchestration: import fungsi generator dari `bab4/sections/*.py`, memanggilnya per subbab, lalu menulis manifest validasi ke `bab4/outputs/`.

# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
import sys

ROOT = Path.cwd().resolve()
while not (ROOT / "pyproject.toml").exists() and ROOT.parent != ROOT:
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from bab4.artifacts import validate_manifest
from bab4.config import Bab4Config
from bab4.run_all import _write_manifest, _write_validation_report
from bab4.sections.s4_1_1 import generate_4_1_1
from bab4.sections.s4_1_2 import generate_4_1_2
from bab4.sections.s4_2 import generate_4_2
from bab4.sections.s4_3 import generate_4_3
from bab4.sections.s4_4 import generate_4_4_1, generate_4_4_2, generate_4_4_3
from bab4.sections.s4_5_6 import generate_4_5, generate_4_6
from bab4.sections.s4_7_8_9 import generate_4_7, generate_4_8, generate_4_9

def show(rows, limit=20):
    rows = list(rows)
    for row in rows[:limit]:
        print(row)
    if len(rows) > limit:
        print(f"... {len(rows) - limit} more rows")

def show_result(result):
    show(artifact.to_record() for artifact in result.artifacts)

config = Bab4Config.from_repo(ROOT)
if config.clean_outputs:
    config.reset_output_dirs()
else:
    config.ensure_output_dirs()
results = []
print(f"Output root: {config.output_root}")
# Out:
# Output root: /home/nozomi/Productive/skripsi/bab4/outputs

# %% [markdown]
# ## 4.1.1 Statistik dan Visual Karakter Input

# %%
result = generate_4_1_1(config)
results.append(result)
show_result(result)
# Out:
# {'artifact_id': 'Tabel 4.1', 'kind': 'table', 'section': '4.1.1', 'priority': 'required', 'title': 'Statistik Sentinel-1 VV dan VH hasil normalisasi per wilayah', 'path': '/home/nozomi/Productive/skripsi/bab4/outputs/tables/4_1_1_sentinel1_vv_vh_stats.csv', 'status': 'exists', 'source': 'dataset/features_preprocessed/*/{vv_norm.tif,vh_norm.tif,feature_valid_mask.tif}', 'note': '', 'size_bytes': 565, 'rows': 11, 'columns': 6, 'width': None, 'height': None}
# {'artifact_id': 'Tabel 4.2', 'kind': 'table', 'section': '4.1.1', 'priority': 'required', 'title': 'Validitas Sentinel-2 per wilayah', 'path': '/home/nozomi/Productive/skripsi/bab4/outputs/tables/4_1_1_s2_valid_mask_by_region.csv', 'status': 'exists', 'source': 'dataset/features_preprocessed/*/{s2_valid_mask.tif,feature_valid_mask.tif}', 'note': '', 'size_bytes': 449, 'rows': 11, 'columns': 4, 'width': None, 'height': None}
# ...

# %% [markdown]
# ## 4.1.2 Alignment Raster dan Overlay OSM Offline

# %%
result = generate_4_1_2(config)
results.append(result)
show_result(result)
# Out:
# {'artifact_id': 'Tabel 4.4', 'kind': 'table', 'section': '4.1.2', 'priority': 'required', 'title': 'Hasil verifikasi alignment raster multisensor per wilayah', 'path': '/home/nozomi/Productive/skripsi/bab4/outputs/tables/4_1_2_alignment_verification.csv', 'status': 'exists', 'source': 'dataset/features_preprocessed/*/*.tif', 'note': '', 'size_bytes': 608, 'rows': 11, 'columns': 5, 'width': None, 'height': None}
# {'artifact_id': 'Tabel 4.5', 'kind': 'table', 'section': '4.1.2', 'priority': 'required', 'title': 'Verifikasi layer dalam stack_7ch.tif pada wilayah Aceh Utara', 'path': '/home/nozomi/Productive/skripsi/bab4/outputs/tables/4_1_2_stack_7ch_layer_verification.csv', 'status': 'exists', 'source': 'dataset/features_preprocessed/Aceh_Utara/stack_7ch.tif', 'note': '', 'size_bytes': 435, 'rows': 7, 'columns': 6, 'width': None, 'height': None}
# ...

# %% [markdown]
# ## 4.2 Label UNOSAT dan Dataset Tile

# %%
result = generate_4_2(config)
results.append(result)
show_result(result)
# Out:
# {'artifact_id': 'Tabel 4.6', 'kind': 'table', 'section': '4.2', 'priority': 'required', 'title': 'Statistik label UNOSAT dan mask per wilayah', 'path': '/home/nozomi/Productive/skripsi/bab4/outputs/tables/4_2_label_mask_tile_stats.csv', 'status': 'exists', 'source': 'dataset/preprocessing_summary.csv', 'note': '', 'size_bytes': 557, 'rows': 11, 'columns': 5, 'width': None, 'height': None}
# {'artifact_id': 'Tabel 4.7', 'kind': 'table', 'section': '4.2', 'priority': 'required', 'title': 'Statistik label UNOSAT dibandingkan valid mask', 'path': '/home/nozomi/Productive/skripsi/bab4/outputs/tables/4_2_label_valid_mask_percentage.csv', 'status': 'exists', 'source': 'dataset/preprocessing_summary.csv', 'note': '', 'size_bytes': 341, 'rows': 11, 'columns': 4, 'width': None, 'height': None}
# ...

# %% [markdown]
# ## 4.3 Spatial Cross-Validation

# %%
result = generate_4_3(config)
results.append(result)
show_result(result)
# Out:
# {'artifact_id': 'Tabel 4.9', 'kind': 'table', 'section': '4.3', 'priority': 'required', 'title': 'Pembagian 5-fold spatial cross-validation', 'path': '/home/nozomi/Productive/skripsi/bab4/outputs/tables/4_3_five_fold_spatial_cv.csv', 'status': 'exists', 'source': 'scripts/preprocessing_utils.py;dataset/preprocessing_summary.csv', 'note': '', 'size_bytes': 666, 'rows': 5, 'columns': 4, 'width': None, 'height': None}
# {'artifact_id': 'Gambar 4.7', 'kind': 'figure', 'section': '4.3', 'priority': 'required', 'title': 'Jumlah tile train, validation, dan final test per fold', 'path': '/home/nozomi/Productive/skripsi/bab4/outputs/figures/4_3_fold_tile_counts.png', 'status': 'exists', 'source': 'scripts/preprocessing_utils.py;dataset/preprocessing_summary.csv', 'note': '', 'size_bytes': 68362, 'rows': None, 'columns': None, 'width': 2329, 'height': 1291}
# ...

# %% [markdown]
# ## 4.4.1 Implementasi Arsitektur Model

# %%
result = generate_4_4_1(config)
results.append(result)
show_result(result)
# Out:
# {'artifact_id': 'Tabel 4.10', 'kind': 'table', 'section': '4.4.1', 'priority': 'required', 'title': 'Spesifikasi implementasi arsitektur U-Net dan ProCANet', 'path': '/home/nozomi/Productive/skripsi/bab4/outputs/tables/4_4_1_model_architecture_specs.csv', 'status': 'exists', 'source': 'training/models/unet.py;training/models/procanet.py;training/models/blocks.py;runs/unet/fold_0/grid_lr_5e-5_wd_1e-4/config.json;runs/procanet/fold_0/grid_lr_1e-4_wd_1e-4/config.json', 'note': '', 'size_bytes': 1190, 'rows': 14, 'columns': 3, 'width': None, 'height': None}
# {'artifact_id': 'Tabel 4.11', 'kind': 'table', 'section': '4.4.1', 'priority': 'required', 'title': 'Hasil verifikasi forward pass model', 'path': '/home/nozomi/Productive/skripsi/bab4/outputs/tables/4_4_1_forward_pass_verification.csv', 'status': 'exists', 'source': 'training/models/unet.py;training/models/procanet.py;tests/test_models.py', 'note': '', 'size_bytes': 215, 'rows': 2, 'columns': 5, 'width': None, 'height': None}
# ...

# %% [markdown]
# ## 4.4.2 Grid Search Hyperparameter

# %%
result = generate_4_4_2(config)
results.append(result)
show_result(result)
# Out:
# {'artifact_id': 'Tabel 4.12', 'kind': 'table', 'section': '4.4.2', 'priority': 'required', 'title': 'Hasil grid search hyperparameter U-Net dan ProCANet', 'path': '/home/nozomi/Productive/skripsi/bab4/outputs/tables/4_4_2_hyperparameter_tuning_summary.csv', 'status': 'exists', 'source': 'runs/{unet,procanet}/fold_*/grid_*/metrics.csv', 'note': '', 'size_bytes': 353, 'rows': 6, 'columns': 7, 'width': None, 'height': None}
# {'artifact_id': 'Gambar 4.10', 'kind': 'figure', 'section': '4.4.2', 'priority': 'required', 'title': 'Perbandingan mean validation IoU per kombinasi hyperparameter', 'path': '/home/nozomi/Productive/skripsi/bab4/outputs/figures/4_4_2_hyperparameter_mean_iou_comparison.png', 'status': 'exists', 'source': 'runs/{unet,procanet}/fold_*/grid_*/metrics.csv', 'note': '', 'size_bytes': 69947, 'rows': None, 'columns': None, 'width': 2759, 'height': 1346}
# ...

# %% [markdown]
# ## 4.4.3 Kurva Stabilitas Pelatihan

# %%
result = generate_4_4_3(config)
results.append(result)
show_result(result)
# Out:
# {'artifact_id': 'Gambar 4.11', 'kind': 'figure', 'section': '4.4.3', 'priority': 'required', 'title': 'Kurva stabilitas pelatihan pada konfigurasi terbaik', 'path': '/home/nozomi/Productive/skripsi/bab4/outputs/figures/4_4_3_training_curves.png', 'status': 'exists', 'source': 'runs/unet/fold_0/grid_lr_5e-5_wd_1e-4/metrics.csv;runs/procanet/fold_0/grid_lr_1e-4_wd_1e-4/metrics.csv', 'note': '', 'size_bytes': 306272, 'rows': None, 'columns': None, 'width': 2666, 'height': 1845}
# {'artifact_id': 'Narasi 4.4.3', 'kind': 'narrative', 'section': '4.4.3', 'priority': 'required', 'title': 'Interpretasi stabilitas training', 'path': '/home/nozomi/Productive/skripsi/bab4/outputs/narratives/4_4_3_training_stability_interpretation.md', 'status': 'exists', 'source': 'runs/unet/fold_0/grid_lr_5e-5_wd_1e-4/metrics.csv;runs/procanet/fold_0/grid_lr_1e-4_wd_1e-4/metrics.csv', 'note': '', 'size_bytes': 458, 'rows': None, 'columns': None, 'width': None, 'height': None}

# %% [markdown]
# ## 4.5 Evaluasi Final

# %%
result = generate_4_5(config)
results.append(result)
show_result(result)
# Out:
# {'artifact_id': 'Tabel 4.13', 'kind': 'table', 'section': '4.5', 'priority': 'required', 'title': 'Metrik checkpoint terbaik spatial CV pada wilayah uji Aceh Utara', 'path': '/home/nozomi/Productive/skripsi/bab4/outputs/tables/4_5_final_metrics.csv', 'status': 'exists', 'source': 'runs/cv_best_checkpoint_eval/{unet,procanet}/eval_test/metrics.csv', 'note': '', 'size_bytes': 163, 'rows': 2, 'columns': 8, 'width': None, 'height': None}
# {'artifact_id': 'Tabel 4.14', 'kind': 'table', 'section': '4.5', 'priority': 'required', 'title': 'Confusion matrix piksel pada wilayah uji Aceh Utara', 'path': '/home/nozomi/Productive/skripsi/bab4/outputs/tables/4_5_confusion_matrix_pixels.csv', 'status': 'exists', 'source': 'runs/cv_best_checkpoint_eval/{unet,procanet}/eval_test/metrics.csv', 'note': '', 'size_bytes': 138, 'rows': 2, 'columns': 7, 'width': None, 'height': None}
# ...

# %% [markdown]
# ## 4.6 Panel Visual dan Error Map

# %%
result = generate_4_6(config)
results.append(result)
show_result(result)
# Out:
# {'artifact_id': 'Tabel 4.15', 'kind': 'table', 'section': '4.6', 'priority': 'required', 'title': 'Jumlah piksel error map pada tile Aceh_Utara_r001280_c005632', 'path': '/home/nozomi/Productive/skripsi/bab4/outputs/tables/4_6_error_map_tile_counts.csv', 'status': 'exists', 'source': 'dataset/tiles/7ch/by_region/Aceh_Utara/Aceh_Utara_r001280_c005632.npz;runs/cv_best_checkpoint_eval/{unet,procanet}/eval_test/predictions/Aceh_Utara/Aceh_Utara_r001280_c005632.npz', 'note': '', 'size_bytes': 186, 'rows': 2, 'columns': 8, 'width': None, 'height': None}
# ...

# %% [markdown]
# ## 4.7 Pembahasan U-Net vs ProCANet

# %%
result = generate_4_7(config)
results.append(result)
show_result(result)
# Out:
# {'artifact_id': 'Tambahan 4.7', 'kind': 'table', 'section': '4.7', 'priority': 'supplementary', 'title': 'Ringkasan perbandingan U-Net vs ProCANet', 'path': '/home/nozomi/Productive/skripsi/bab4/outputs/tables/4_7_unet_vs_procanet_effectiveness_summary.csv', 'status': 'exists', 'source': 'runs/cv_best_checkpoint_eval/{unet,procanet}/eval_test/metrics.csv;training/models/{unet,procanet}.py', 'note': '', 'size_bytes': 575, 'rows': 2, 'columns': 12, 'width': None, 'height': None}
# {'artifact_id': 'Tambahan 4.7b', 'kind': 'table', 'section': '4.7', 'priority': 'supplementary', 'title': 'Konteks perbandingan literatur', 'path': '/home/nozomi/Productive/skripsi/bab4/outputs/tables/4_7_literature_context_comparison.csv', 'status': 'exists', 'source': 'runs/cv_best_checkpoint_eval/{unet,procanet}/eval_test/metrics.csv;training/models/{unet,procanet}.py', 'note': '', 'size_bytes': 646, 'rows': 3, 'columns': 4, 'width': None, 'height': None}
# ...

# %% [markdown]
# ## 4.8 Kasus Data Ekstrem

# %%
result = generate_4_8(config)
results.append(result)
show_result(result)
# Out:
# {'artifact_id': 'Tabel 4.16', 'kind': 'table', 'section': '4.8', 'priority': 'required', 'title': 'Kondisi data sulit per wilayah', 'path': '/home/nozomi/Productive/skripsi/bab4/outputs/tables/4_8_difficult_data_case_studies.csv', 'status': 'exists', 'source': 'dataset/tiles/7ch/by_region/*/*.npz;dataset/feature_preprocessing_summary.csv', 'note': '', 'size_bytes': 484, 'rows': 7, 'columns': 7, 'width': None, 'height': None}
# {'artifact_id': 'Tabel 4.17', 'kind': 'table', 'section': '4.8', 'priority': 'required', 'title': 'Contoh tile kondisi ekstrem', 'path': '/home/nozomi/Productive/skripsi/bab4/outputs/tables/4_8_extreme_tile_selection.csv', 'status': 'exists', 'source': 'dataset/tiles/7ch/by_region/*/*.npz', 'note': '', 'size_bytes': 450, 'rows': 3, 'columns': 9, 'width': None, 'height': None}
# ...

# %% [markdown]
# ## 4.9 Ringkasan Temuan BAB 4

# %%
result = generate_4_9(config)
results.append(result)
show_result(result)
# Out:
# {'artifact_id': 'Tambahan 4.9', 'kind': 'table', 'section': '4.9', 'priority': 'supplementary', 'title': 'Ringkasan temuan utama BAB 4', 'path': '/home/nozomi/Productive/skripsi/bab4/outputs/tables/4_9_bab4_findings_summary.csv', 'status': 'exists', 'source': 'dataset/preprocessing_summary.csv;runs/cv_best_checkpoint_eval/{unet,procanet}/eval_test/metrics.csv;bab4 generator functions', 'note': '', 'size_bytes': 680, 'rows': 4, 'columns': 4, 'width': None, 'height': None}

# %% [markdown]
# ## Manifest Validasi

# %%
manifest = validate_manifest(config, results)
_write_manifest(config, manifest)
_write_validation_report(config, manifest)
print(manifest.status_counts())
show(manifest.select(["artifact_id", "kind", "section", "status", "source", "path"]), limit=60)
# Out:
# {'exists': 49}
# {'artifact_id': 'Gambar 4.1', 'kind': 'figure', 'section': '4.1.1', 'status': 'exists', 'source': 'dataset/tiles/7ch/by_region/*/*.npz', 'path': '/home/nozomi/Productive/skripsi/bab4/outputs/figures/4_1_1_s2_valid_vs_empty_comparison.png'}
# {'artifact_id': 'Gambar 4.2', 'kind': 'figure', 'section': '4.1.1', 'status': 'exists', 'source': 'dataset/features_preprocessed/Aceh_Utara/', 'path': '/home/nozomi/Productive/skripsi/bab4/outputs/figures/4_1_1_channel_example_aceh_utara.png'}
# {'artifact_id': 'Gambar 4.3', 'kind': 'figure', 'section': '4.1.2', 'status': 'exists', 'source': 'dataset/tiles/7ch/by_region/Aceh_Utara/Aceh_Utara_r001280_c005632.npz;cache/*.json;dataset/satelit raw/Aceh Utara', 'path': '/home/nozomi/Productive/skripsi/bab4/outputs/figures/4_1_2_osm_overlay_stack_aceh_utara.png'}
# ...
